# %% [markdown]
# This notebook was created by Donna Faith Go.

# %%
import sys
# !{sys.executable} -m pip install -qq -r requirements.txt

# %%
# standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os
import re

# data gathering
import yfinance as yf
import time
import pandas_datareader.data as web
from datetime import datetime, timedelta

# ignore warnings
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## Daily Closing Prices

# %% [markdown]
# ## Stock Tickers

# %%
filepath = 'SSE companies list.pkl'
with open(filepath, 'rb') as f:
    companies_df = pickle.load(f)
companies_df.head()
companies_df = companies_df[:900]

# %%
# add the suffix to make it compatible with yfinance
tickers_list = companies_df['Company Code'].to_list()
tickers_list = [ticker + ".SS" for ticker in tickers_list]

# check if it worked
print(tickers_list[:5])
# Out:
# ['600000.SS', '600004.SS', '600006.SS', '600007.SS', '600008.SS']

# %%
# sanity checks
print(tickers_list[0])
print(companies_df['Company Name'][0])
print(len(companies_df) == len(tickers_list)) # should be True
# Out:
# 600000.SS
# SHANGHAI PUDONG DEVELOPMENT BANK CO., LTD.
# True

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Some company names have forbidden characters which can hinder them from becoming a file name.
# They have to be removed.

# %%
# forbidden Windows filename characters
forbidden_chars = r'[<>:"/\\|?*]'

# remove forbidden characters
companies_df['Safe Name'] = companies_df['Company Name'].apply(lambda x: re.sub(forbidden_chars, '', x))

# Optional: strip extra spaces at the ends
companies_df['Safe Name'] = companies_df['Safe Name'].str.strip()

print(companies_df)

# %% [markdown]
# ## yfinance

# %%
# pull individual stock data from yfinance
def download_info_per_stock(ticker, verbose=False, 
                            start_date='2000-01-01', 
                            end_date='2026-01-01'):
        try:
            # get data for the ticker
            ticker_data = yf.download(
                ticker,
                start=start_date,
                end=end_date,
                progress=False,
                timeout=120 # in case of slow internet, in seconds
            )
            return pd.DataFrame(ticker_data)
            
        except Exception as e:
            if verbose:
                print(f"Error downloading {ticker}.")
            return None

# saving individual stock data
def save_info_per_stock(ticker_list, delay=1, 
                        verbose=False, override=False,
                        start_date='2000-01-01', 
                        end_date='2026-01-01'):
    
    # create the data folder
    os.makedirs("data", exist_ok=True)

    for i in range(0, len(ticker_list)):
        # declare company name and filepath
        ticker_name = companies_df['Company Name'][i]
        filepath = f"data/{ticker_name}.pkl"

        # skip if not override and file exists
        if override == False and os.path.exists(filepath):
            if verbose:
                print(f"Skipped {ticker_name}.")
                continue
        else:                    
            # get the data for each stock
            if verbose:
                print()
                print(f"Downloading for ticker: {ticker_list[i]}")
            ticker_data = download_info_per_stock(ticker_list[i],
                                                  start_date=start_date,
                                                  end_date=end_date)
    
            # saving data as a pkl file
            if ticker_data is not None and not ticker_data.empty:
                ticker_data.to_pickle(filepath)
                if verbose == True:
                    print(f"Saved data for {ticker_name}.")
            
            # avoid rate limiting
            time.sleep(delay)

    print("Done downloading all data!")

# %%
save_info_per_stock(tickers_list, verbose=True)
# Out:
# Skipped SHANGHAI PUDONG DEVELOPMENT BANK CO., LTD..
# Skipped Guangzhou Baiyun International Airport Co.,ltd..
# Skipped Dongfeng  Automobile  Co.,LTD.
# Skipped China World Trade Center Company Ltd..
# Skipped Beijing Capital Eco-Environment Protection Group Co.,Ltd..
# Skipped Shanghai International Airport Co., Ltd..
# Skipped ZHEJIANG QIANJIANG BIOCHEMICAL COMPANY LIMITED.
# Skipped INSIGMA TECHNOLOGY CO.,LTD..
# Skipped NINGBO MARINE COMPANY LIMITED..
# Skipped TIAN JIN BOHAI CHEMICAL CO.,LTD..
# Skipped HUAXIN BUILDING MATERIALS GROUP CO., LTD..
# Skipped FUJIAN CEMENT INC..
# Skipped ENN Natural Gas Co., Ltd..
# Skipped Jiangsu Yueda Investment Co.Ltd..
# Skipped Jinan High-tech Development Co., Ltd..
# Skipped MAANSHAN IRON & STEEL COMPANY LIMITED.
# Skipped SHANXI XINGHUACUN FEN WINE FACTORY  CO.,LTD.
# Skipped SHEN MA INDUSTRY CO.,LTD.
# Skipped NORTH CHINA PHARMACEUTICAL COMPANY. LTD.
# Skipped HANGZHOU JIEBAI GROUP CO., LIMITED..
# Skipped Xiamen XGMA Machinery Company Limited..
# Skipped J-Yuan Trust Co.,Ltd..
# Skipped YUTONG HEAVY INDUSTRIES CO.,LTD..
# Skipped ZHONGLU CO,.LTD..
#
# Downloading for ticker: 600819.SS
# Saved data for SHANGHAI YAOHUA PILKINGTON GLASS GROUP CO,LTD..
#
# Downloading for ticker: 600820.SS
# Saved data for SHANGHAI TUNNEL ENGINEERING CO.,LTD..
#
# Downloading for ticker: 600821.SS
# Saved data for NYOCOR Company Limited.
#
# Downloading for ticker: 600822.SS
# Saved data for Shanghai Material Trading Co., Ltd..
#
# Downloading for ticker: 600824.SS
# Saved data for SHANGHAI YIMIN COMMERCIAL GROUP CO., LTD..
#
# Downloading for ticker: 600825.SS
# Saved data for Shanghai Xinhua Media Co., Ltd.
#
# Downloading for ticker: 600826.SS
# Saved data for DLG EXHIBITIONS & EVENTS CORPORATION LIMITED.
#
# Downloading for ticker: 600827.SS
# Saved data for SHANGHAI BAILIAN GROUP CO., LTD..
#
# Downloading for ticker: 600828.SS
# Saved data for Maoye Commercial Co.,Ltd..
#
# Downloading for ticker: 600829.SS
# Saved data for HPGC Renmintongtai Pharmaceutical Corporation.
#
# Downloading for ticker: 600830.SS
# Saved data for SUNNY LOAN TOP CO.,LTD.
#
# Downloading for ticker: 600831.SS
# Saved data for SHAANXI BROADCAST & TV NETWORK INTERMEDIARY （GROUP）CO.LTD.
#
# Downloading for ticker: 600833.SS
# Saved data for SHANGHAI NO.1 PHARMACY CO.,LTD..
#
# Downloading for ticker: 600834.SS
# Saved data for Shanghai Shentong Metro Co., Ltd..
#
# Downloading for ticker: 600835.SS
# Saved data for Shanghai Mechanical & Electrical Industry CO., LTD..
#
# Downloading for ticker: 600838.SS
# Saved data for SHANGHAI JOIN BUY CO.,LTD..
#
# Downloading for ticker: 600839.SS
# Saved data for SICHUAN CHANGHONG ELECTRIC CO.,LTD..
#
# Downloading for ticker: 600841.SS
# Saved data for Shanghai New Power Automotive Technology Company Limited.
#
# Downloading for ticker: 600843.SS
# Saved data for Shang Gong Group Co., Ltd..
#
# Downloading for ticker: 600844.SS
# Saved data for Inner Mongolia Jinmei Chemical Technology Co., Ltd..
#
# Downloading for ticker: 600845.SS
# Saved data for Shanghai Baosight Software Co., Ltd..
#
# Downloading for ticker: 600846.SS
# Saved data for SHANGHAI TONGJI SCIENCE & TECHNOLOGY INDUSTRIAL CO.,LTD.
#
# Downloading for ticker: 600847.SS
# Saved data for Chongqing Wanli New Energy Co.,Ltd..
#
# Downloading for ticker: 600848.SS
# Saved data for Shanghai Lingang Holdings Corporation Limited.
#
# Downloading for ticker: 600850.SS
# Saved data for CETC Digital Technology Co.,Ltd..
#
# Downloading for ticker: 600851.SS
# Saved data for SHANGHAI HAIXIN GROUP CO., LTD..
#
# Downloading for ticker: 600853.SS
# Saved data for LONGJIAN ROAD & BRIDGE CO.,LTD..
#
# Downloading for ticker: 600854.SS
# Saved data for JIANGSU CHUNLAN REFRIGERATING EQUIPMENT STOCK CO.,LTD.
#
# Downloading for ticker: 600855.SS
# Saved data for BEIJING AEROSPACE CHANGFENG CO.,LTD..
#
# Downloading for ticker: 600857.SS
# Saved data for NINGBO ZHONGBAI CO., LTD..
#
# Downloading for ticker: 600858.SS
# Saved data for INZONE GROUP CO.,LTD.
#
# Downloading for ticker: 600859.SS
# Saved data for WANGFUJING GROUP CO., LTD..
#
# Downloading for ticker: 600860.SS
# Saved data for Beijing Jingcheng Machinery Electric Company Limited.
#
# Downloading for ticker: 600861.SS
# Saved data for FESCO Group Co., Ltd.
#
# Downloading for ticker: 600862.SS
# Saved data for Avic Aviation High-Technology  Co., Ltd..
#
# Downloading for ticker: 600863.SS
# Saved data for INNER MONGOLIA MENGDIAN HUANENG THERMAL POWER CORPORATION LI.
#
# Downloading for ticker: 600864.SS
# Saved data for HARBIN HATOU INVESTMENT CO.,LTD.
#
# Downloading for ticker: 600865.SS
# Saved data for BAIDA GROUP CO.,LTD.
#
# Downloading for ticker: 600866.SS
# Saved data for STAR LAKE BIOSCIENCE CO.,INC. ZHAOQING GUANGDONG.
#
# Downloading for ticker: 600867.SS
# Saved data for TONGHUA DONGBAO PHARMACEUTICAL CO.,LTD..
#
# Downloading for ticker: 600868.SS
# Saved data for Guangdong Meiyan jixiang Hydropower Co.,Ltd..
#
# Downloading for ticker: 600869.SS
# Saved data for Far East Smarter Energy Co.,Ltd.
#
# Downloading for ticker: 600871.SS
# Saved data for SINOPEC OILFIELD SERVICE CORPORATION.
#
# Downloading for ticker: 600872.SS
# Saved data for JONJEE HI-TECH INDUSTRIAL & COMMERCIAL HOLDING CO.,LTD.
#
# Downloading for ticker: 600873.SS
# Saved data for MeiHua Holdings Group Co.,Ltd.
#
# Downloading for ticker: 600874.SS
# Saved data for Tianjin Capital Environmental Protection Group Company Limited.
#
# Downloading for ticker: 600875.SS
# Saved data for DONGFANG ELECTRIC CORPORATION LIMITED.
#
# Downloading for ticker: 600876.SS
# Saved data for Triumph New Energy Company Limited.
#
# Downloading for ticker: 600877.SS
# Saved data for CETC Chips Technology Inc..
#
# Downloading for ticker: 600879.SS
# Saved data for China Aerospace Times Electronics CO., LTD..
#
# Downloading for ticker: 600880.SS
# Saved data for Chengdu B-ray Media Co.,Ltd.
#
# Downloading for ticker: 600881.SS
# Saved data for JILIN YATAI (GROUP) CO., LTD..
#
# Downloading for ticker: 600882.SS
# Saved data for Shanghai Milkground Food Tech Co., Ltd..
#
# Downloading for ticker: 600883.SS
# Saved data for Yunnan Bowin Technology&Industry Co.,Ltd..
#
# Downloading for ticker: 600884.SS
# Saved data for NINGBO SHANSHAN CO.,LTD..
#
# Downloading for ticker: 600885.SS
# Saved data for Hongfa Technology Co.，Ltd..
#
# Downloading for ticker: 600886.SS
# Saved data for SDIC Power Holdings Co.,Ltd..
#
# Downloading for ticker: 600887.SS
# Saved data for INNER MONGOLIA YILI INDUSTRIAL GROUP CO.,LTD.
#
# Downloading for ticker: 600888.SS
# Saved data for XINJIANG JOINWORLD CO.,LTD..
#
# Downloading for ticker: 600889.SS
# Saved data for NANJING CHEMICAL FIBRE CO.LTD.
#
# Downloading for ticker: 600893.SS
# Saved data for AECC AVIATION POWER CO,LTD..
#
# Downloading for ticker: 600894.SS
# Saved data for GUANGZHOU GUANGRI STOCK CO.,LTD..
#
# Downloading for ticker: 600895.SS
# Saved data for SHANGHAI ZHANGJIANG HI-TECH PARK DEVELOPMENT CO.,LTD.
#
# Downloading for ticker: 600897.SS
# Saved data for Xiamen International Airport Co.,Ltd.
#
# Downloading for ticker: 600900.SS
# Saved data for China Yangtze Power Co.,ltd..
#
# Downloading for ticker: 600901.SS
# Saved data for Jiangsu Financial Leasing Co.,Ltd..
#
# Downloading for ticker: 600903.SS
# Saved data for Guizhou Gas Group Corporation Ltd..
#
# Downloading for ticker: 600905.SS
# Saved data for China Three Gorges Renewables (Group) Co., Ltd..
#
# Downloading for ticker: 600906.SS
# Saved data for CAIDA SECURITIES CO.，LTD..
#
# Downloading for ticker: 600908.SS
# Saved data for Wuxi Rural Commercial Bank Co., Ltd..
#
# Downloading for ticker: 600909.SS
# Saved data for HUAAN SECURITIES CO., LTD..
#
# Downloading for ticker: 600916.SS
# Saved data for China National Gold Group Gold Jewellery Co.,Ltd.
#
# Downloading for ticker: 600917.SS
# Saved data for Chongqing Gas Group Corporation Ltd..
#
# Downloading for ticker: 600918.SS
# Saved data for ZHONGTAI SECURITIES CO., LTD..
#
# Downloading for ticker: 600919.SS
# Saved data for BANK OF JIANGSU CO., LTD..
#
# Downloading for ticker: 600925.SS
# Saved data for Jiangsu Xukuang Energy Co. Ltd.
#
# Downloading for ticker: 600926.SS
# Saved data for BANK OF HANGZHOU CO.,LTD..
#
# Downloading for ticker: 600927.SS
# Saved data for YONGAN FUTURES CO.,LTD..
#
# Downloading for ticker: 600928.SS
# Saved data for BANK OF XI'AN CO.,LTD..
#
# Downloading for ticker: 600929.SS
# Saved data for Snowsky Salt Industry Group Co.,Ltd.
#
# Downloading for ticker: 600933.SS
# Saved data for IKD Co., Ltd..
#
# Downloading for ticker: 600935.SS
# Saved data for ANHUI HWASU CO.,LTD..
#
# Downloading for ticker: 600936.SS
# Saved data for 600936.
#
# Downloading for ticker: 600938.SS
# Saved data for CNOOC Limited.
#
# Downloading for ticker: 600939.SS
# Saved data for CHONGQING CONSTRUCTION ENGINEERING GROUP CORPORATION LIMITED.
#
# Downloading for ticker: 600941.SS
# Saved data for 600941.
#
# Downloading for ticker: 600955.SS
# Saved data for Lihuayi Weiyuan Chemical Co., Ltd..
#
# Downloading for ticker: 600956.SS
# Saved data for China Suntien Green Energy Corporation Limited.
#
# Downloading for ticker: 600958.SS
# Saved data for ORIENT SECURITIES COMPANY LIMITED.
#
# Downloading for ticker: 600959.SS
# Saved data for Jiangsu Broadcasting Cable Information Network Corporation Limited.
#
# Downloading for ticker: 600960.SS
# Saved data for Bohai Automotive Systems CO.，LTD..
#
# Downloading for ticker: 600961.SS
# Saved data for ZHUZHOU SMELTER GROUP CO.,LTD..
#
# Downloading for ticker: 600962.SS
# Saved data for SDIC ZHONGLU FRUIT JUICE CO.,LTD..
#
# Downloading for ticker: 600963.SS
# Saved data for YUEYANG FOREST ＆ PAPER CO., LTD..
#
# Downloading for ticker: 600965.SS
# Saved data for Fortune Ng Fung Food (Hebei) Co., Ltd.
#
# Downloading for ticker: 600966.SS
# Saved data for SHANDONG  BOHUI PAPER INDUSTRIAL  CO.,LTD..
#
# Downloading for ticker: 600967.SS
# Saved data for Inner Mongolia First Machinery Group Co.,Ltd..
#
# Downloading for ticker: 600968.SS
# Saved data for CNOOC Energy Technology & Services Limited.
#
# Downloading for ticker: 600969.SS
# Saved data for Hunan Chendian International Development Share-holding Limited company.
#
# Downloading for ticker: 600970.SS
# Saved data for Sinoma International Engineering Co.,Ltd..
#
# Downloading for ticker: 600971.SS
# Saved data for Anhui Hengyuan Coal Industry and Electricity Power Co., Ltd..
#
# Downloading for ticker: 600973.SS
# Saved data for BAOSHENG SCIENCE AND TECHNOLOGY INNOVATION CO., LTD..
#
# Downloading for ticker: 600975.SS
# Saved data for Hunan New Wellfull Co.,Ltd..
#
# Downloading for ticker: 600976.SS
# Saved data for JIANMIN PHARMACEUTICAL GROUP CO.，LTD..
#
# Downloading for ticker: 600977.SS
# Saved data for CHINA FILM GROUP CO.,LTD..
#
# Downloading for ticker: 600979.SS
# Saved data for SICHUAN GUANGAN AAA PUBLIC CO.,LTD ..
#
# Downloading for ticker: 600980.SS
# Saved data for BGRIMM Technology Co.,Ltd..
#
# Downloading for ticker: 600981.SS
# Saved data for JIANGSU SOHO HIGH HOPE GROUP CORPORATION.
#
# Downloading for ticker: 600982.SS
# Saved data for NINGBO ENERGY GROUP CO.,LTD..
#
# Downloading for ticker: 600983.SS
# Saved data for Whirlpool China Co.,Ltd.
#
# Downloading for ticker: 600984.SS
# Saved data for SHAANXI  CONSTRUCTION  MACHINERY  CO.,LTD..
#
# Downloading for ticker: 600985.SS
# Saved data for Huaibei Mining Holdings Co.,Ltd..
#
# Downloading for ticker: 600986.SS
# Saved data for Zhewen Interactive Group Co., Ltd..
#
# Downloading for ticker: 600987.SS
# Saved data for ZHEJIANG HANGMIN CO., LTD..
#
# Downloading for ticker: 600988.SS
# Saved data for Chifeng Jilong Gold Mining Co.,Ltd..
#
# Downloading for ticker: 600989.SS
# Saved data for 600989.
#
# Downloading for ticker: 600990.SS
# Saved data for Sun-Create Electronics Co.,Ltd.
#
# Downloading for ticker: 600992.SS
# Saved data for GUIZHOU WIRE ROPE CO.,LTD.
#
# Downloading for ticker: 600993.SS
# Saved data for Mayinglong Pharmaceutical Group Stock Co.,LTD..
#
# Downloading for ticker: 600995.SS
# Saved data for China Southern Power Grid Energy Storage Co.,Ltd.
#
# Downloading for ticker: 600996.SS
# Saved data for Guizhou BC&TV Information Network CO.,LTD.
#
# Downloading for ticker: 600997.SS
# Saved data for KAILUAN ENERGY CHEMICAL CORPORATION LIMITED.
#
# Downloading for ticker: 600998.SS
# Saved data for Jointown Pharmaceutical Group Company Limited.
#
# Downloading for ticker: 600999.SS
# Saved data for China Merchants Securities Co.,Ltd..
#
# Downloading for ticker: 601000.SS
# Saved data for TANGSHAN PORT GROUP CO.,LTD..
#
# Downloading for ticker: 601001.SS
# Saved data for Jinneng Holding Shanxi Coal Industry Co.,Ltd..
#
# Downloading for ticker: 601002.SS
# Saved data for GEM-YEAR INDUSTRIAL CO.,LTD..
#
# Downloading for ticker: 601003.SS
# Saved data for LIUZHOU IRON&STEEL CO.,LCD.
#
# Downloading for ticker: 601005.SS
# Saved data for CHONGQING IRON & STEEL COMPANY LIMITED.
#
# Downloading for ticker: 601006.SS
# Saved data for Daqin Railway Co., Ltd..
#
# Downloading for ticker: 601007.SS
# Saved data for Jinling Hotel Corporation,Ltd..
#
# Downloading for ticker: 601008.SS
# Saved data for Jiangsu Lianyungang Port Co.,Ltd..
#
# Downloading for ticker: 601009.SS
# Saved data for BANK OF NANJING CO., LTD.
#
# Downloading for ticker: 601010.SS
# Saved data for Wenfeng Great World Chain Development  Corporation.
#
# Downloading for ticker: 601011.SS
# Saved data for Baotailong New Materials Co., Ltd..
#
# Downloading for ticker: 601012.SS
# Saved data for LONGi Green Energy Technology Co., Ltd..
#
# Downloading for ticker: 601015.SS
# Saved data for Shaanxi Heimao Coking Co., Ltd.
#
# Downloading for ticker: 601016.SS
# Saved data for CECEP Wind-Power Corporation.
#
# Downloading for ticker: 601018.SS
# Saved data for Ningbo Zhoushan Port Company Limited.
#
# Downloading for ticker: 601019.SS
# Saved data for Shandong Publishing&Media Co.,Ltd.
#
# Downloading for ticker: 601020.SS
# Saved data for 601020.
#
# Downloading for ticker: 601021.SS
# Saved data for Spring Airlines Co., Ltd..
#
# Downloading for ticker: 601022.SS
# Saved data for Ningbo Ocean Shipping Co., Ltd..
#
# Downloading for ticker: 601033.SS
# Saved data for 601033.
#
# Downloading for ticker: 601038.SS
# Saved data for FIRST TRACTOR COMPANY LIMITED.
#
# Downloading for ticker: 601058.SS
# Saved data for SAILUN GROUP CO.,LTD..
#
# Downloading for ticker: 601059.SS
# Saved data for CINDA SECURITIES CO.,LTD.
#
# Downloading for ticker: 601061.SS
# Saved data for CITIC Metal Co., Ltd.
#
# Downloading for ticker: 601065.SS
# Saved data for Jiangxi Salt Industry Group Co., Ltd.
#
# Downloading for ticker: 601066.SS
# Saved data for CHINA SECURITIES CO., LTD..
#
# Downloading for ticker: 601068.SS
# Saved data for China Aluminum International Engineering Corporation Limited.
#
# Downloading for ticker: 601069.SS
# Saved data for Western Region Gold Co., Ltd..
#
# Downloading for ticker: 601077.SS
# Saved data for Chongqing Rural Commercial Bank Co., Ltd..
#
# Downloading for ticker: 601083.SS
# Saved data for SHANGHAI JINJIANG SHIPPING (GROUP) CO.,LTD..
#
# Downloading for ticker: 601086.SS
# Saved data for GANSU GUOFANG INDUSTRY & TRADE（GROUP）CO.,LTD..
#
# Downloading for ticker: 601088.SS
# Saved data for China Shenhua Energy Company Limited.
#
# Downloading for ticker: 601089.SS
# Saved data for Beijing Foyou Pharmaceutical CO.,LTD.
#
# Downloading for ticker: 601096.SS
# Saved data for 601096.
#
# Downloading for ticker: 601098.SS
# Saved data for China South Publishing & Media Group Co.,Ltd..
#
# Downloading for ticker: 601099.SS
# Saved data for THE PACIFIC SECURITIES CO.,LTD.
#
# Downloading for ticker: 601100.SS
# Saved data for jiangsu hengli hydraulic co.Ltd.
#
# Downloading for ticker: 601101.SS
# Saved data for BEIJING HAOHUA ENERGY RESOURCE CO. ,LTD.
#
# Downloading for ticker: 601106.SS
# Saved data for China First Heavy lndustries.
#
# Downloading for ticker: 601107.SS
# Saved data for Sichuan Expressway Company Limited.
#
# Downloading for ticker: 601108.SS
# Saved data for CAITONG SECURITIES CO.,LTD.
#
# Downloading for ticker: 601111.SS
# Saved data for Air China Limited.
#
# Downloading for ticker: 601113.SS
# Saved data for Yiwu Huading Nylon Co.,Ltd..
#
# Downloading for ticker: 601116.SS
# Saved data for SANJIANG SHOPPING CLUB CO.,LTD..
#
# Downloading for ticker: 601117.SS
# Saved data for China National Chemical Engineering CO.,LTD..
#
# Downloading for ticker: 601118.SS
# Saved data for China Hainan Rubber Industry Group Co.,LTD..
#
# Downloading for ticker: 601121.SS
# Saved data for XinjiangBaodiMiningCo.,Ltd..
#
# Downloading for ticker: 601126.SS
# Saved data for BEIJING SIFANG AUTOMATION CO.,LTD..
#
# Downloading for ticker: 601127.SS
# Saved data for Seres Group Co.,Ltd..
#
# Downloading for ticker: 601128.SS
# Saved data for Jiangsu Changshu Rural Commercial Bank Co., Ltd..
#
# Downloading for ticker: 601133.SS
# Saved data for BOTH ENGINEERING TECHNOLOGY CO.,LTD.
#
# Downloading for ticker: 601136.SS
# Saved data for CAPITAL SECURITIES CORPORATION LIMITED.
#
# Downloading for ticker: 601137.SS
# Saved data for Ningbo Boway Alloy Material Co., Ltd.
#
# Downloading for ticker: 601138.SS
# Saved data for Foxconn Industrial Internet Co., Ltd..
#
# Downloading for ticker: 601139.SS
# Saved data for SHENZHEN GAS CORPORATION LTD..
#
# Downloading for ticker: 601155.SS
# Saved data for Seazen Holdings Co.,Ltd..
#
# Downloading for ticker: 601156.SS
# Saved data for Eastern Air Logistics Co., Ltd..
#
# Downloading for ticker: 601158.SS
# Saved data for Chongqing Water Group Co.,Ltd..
#
# Downloading for ticker: 601162.SS
# Saved data for TIANFENG SECURITIES CO., LTD.
#
# Downloading for ticker: 601163.SS
# Saved data for TRIANGLE TYRE CO., LTD..
#
# Downloading for ticker: 601166.SS
# Saved data for INDUSTRIAL BANK CO.,LTD..
#
# Downloading for ticker: 601168.SS
# Saved data for Western Mining Co., Ltd..
#
# Downloading for ticker: 601169.SS
# Saved data for BANK OF BEIJING CO.,LTD..
#
# Downloading for ticker: 601177.SS
# Saved data for Hangzhou Advance Gearbox Group Co., Ltd..
#
# Downloading for ticker: 601179.SS
# Saved data for China XD Electric Co., Ltd..
#
# Downloading for ticker: 601186.SS
# Saved data for China Railway Construction Corporation Limited.
#
# Downloading for ticker: 601187.SS
# Saved data for Xiamen Bank Co.,Ltd..
#
# Downloading for ticker: 601188.SS
# Saved data for HEILONGJIANG TRANSPORT DEVELOPMENT CO., LTD.
#
# Downloading for ticker: 601198.SS
# Saved data for DONGXING SECURITIES CO., LTD..
#
# Downloading for ticker: 601199.SS
# Saved data for Jiangsu Jiangnan Water Co., Ltd..
#
# Downloading for ticker: 601200.SS
# Saved data for SHANGHAI ENVIRONMENT GROUP CO., LTD..
#
# Downloading for ticker: 601208.SS
# Saved data for SICHUAN EM TECHNOLOGY CO.,LTD..
#
# Downloading for ticker: 601211.SS
# Saved data for Guotai Haitong Securities Co. Ltd..
#
# Downloading for ticker: 601212.SS
# Saved data for Baiyin Nonferrous Group Co.,Ltd.
#
# Downloading for ticker: 601216.SS
# Saved data for INNER MONGOLIA JUNZHENG ENERGY & CHEMICAL GROUP CO.,LTD..
#
# Downloading for ticker: 601218.SS
# Saved data for Jiangsu SINOJIT Wind Energy Technology Co,.Ltd..
#
# Downloading for ticker: 601222.SS
# Saved data for JIANGSU LINYANG Energy CO., LTD..
#
# Downloading for ticker: 601225.SS
# Saved data for SHAANXI COAL INDUSTRY COMPANY LIMITED.
#
# Downloading for ticker: 601226.SS
# Saved data for HUADIAN HEAVY INDUSTRIES CO.,LTD..
#
# Downloading for ticker: 601228.SS
# Saved data for guangzhou port company limited.
#
# Downloading for ticker: 601229.SS
# Saved data for Bank of Shanghai Co.,ltd..
#
# Downloading for ticker: 601231.SS
# Saved data for Universal scientific industrial(shanghai)Co.,Ltd..
#
# Downloading for ticker: 601233.SS
# Saved data for TONGKUN GROUP CO,LTD.
#
# Downloading for ticker: 601236.SS
# Saved data for HONGTA SECURITIES CO.,LTD..
#
# Downloading for ticker: 601238.SS
# Saved data for GUANGZHOU AUTOMOBILE GROUP CO.,LTD..
#
# Downloading for ticker: 601279.SS
# Saved data for Changchun Engley Automobile Industry Co.,Ltd..
#
# Downloading for ticker: 601288.SS
# Saved data for AGRICULTURAL BANK OF CHINA LIMITED.
#
# Downloading for ticker: 601298.SS
# Saved data for Qingdao Port International Co., Ltd..
#
# Downloading for ticker: 601311.SS
# Saved data for Camel Group Co.,Ltd..
#
# Downloading for ticker: 601318.SS
# Saved data for PING AN INSURANCE（GROUP） COMPANY OF CHINA, LTD..
#
# Downloading for ticker: 601319.SS
# Saved data for The People's Insurance Company (Group) of China Limited.
#
# Downloading for ticker: 601326.SS
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 save_info_per_stock(tickers_list, verbose=True)
#
# Cell In[6], line 51, in save_info_per_stock(ticker_list, delay, verbose, override, start_date, end_date)
#      49 # saving data as a pkl file
#      50 if ticker_data is not None and not ticker_data.empty:
# ---> 51     ticker_data.to_pickle(filepath)
#      52     if verbose == True:
#      53         print(f"Saved data for {ticker_name}.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3187, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    3137 """
#    3138 Pickle (serialize) object to file.
#    3139
#    (...)   3183 4    4    9
#    3184 """  # noqa: E501
#    3185 from pandas.io.pickle import to_pickle
# -> 3187 to_pickle(
#    3188     self,
#    3189     path,
#    3190     compression=compression,
#    3191     protocol=protocol,
#    3192     storage_options=storage_options,
#    3193 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\pickle.py:103, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     100 if protocol < 0:
#     101     protocol = pickle.HIGHEST_PROTOCOL
# --> 103 with get_handle(
#     104     filepath_or_buffer,
#     105     "wb",
#     106     compression=compression,
#     107     is_text=False,
#     108     storage_options=storage_options,
#     109 ) as handles:
#     110     # letting pickle write directly to the buffer is more memory-efficient
#     111     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# OSError: [Errno 22] Invalid argument: 'data/Qinhuangdao Port Co., Ltd.*.pkl'

# %% [markdown]
# Note: The code above takes around 40-50 minutes to completely run.

# %% [markdown]
# ## Discarded Code

# %% [markdown]
# This code was disregarded because the files it generated were too big to be committed on the GitHub.

# %%
# declare start and end dates
start_date = '2000-01-01'
end_date = '2026-01-01'

def download_stocks_in_batches(tickers, batch_size=5, delay=1, verbose=False):
    """
    Download stock data in batches to avoid rate limiting
    """
    all_data = {}
    
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i + batch_size]
        if verbose:
            print(f"Downloading batch {i//batch_size + 1}: {batch}")
        
        try:
            # Download the batch
            batch_data = yf.download(
                batch,
                start=start_date,
                end=end_date,
                progress=False
            )
            
            # Extract closing prices for this batch
            if not batch_data.empty and 'Close' in batch_data.columns:
                closes = batch_data['Close']
                if isinstance(closes, pd.Series):
                    all_data[batch[0]] = closes
                else:
                    for ticker in closes.columns:
                        all_data[ticker] = closes[ticker]
                if verbose:
                    print(f"Successfully downloaded {len(batch)} stocks")
            else:
                print(f"No data returned for batch: {batch}")
            
        except Exception as e:
            print(f"Error downloading batch {batch}: {e}")
        
        # Add delay to avoid rate limiting
        if i + batch_size < len(tickers):
            if verbose:
                print(f"Waiting {delay} seconds before next batch...")
            time.sleep(delay)
    
    if all_data:
        return pd.DataFrame(all_data)
    else:
        return pd.DataFrame()

# %%
# # Download the closing prices
# closing_df = download_stocks_in_batches(
#     tickers_list, 
#     batch_size=5, 
#     delay=5
# )

# # removing unnecessary columns and rows
# closing_df.dropna(how='all', axis=1, inplace=True)
# closing_df.dropna(how='all', axis=0, inplace=True)

# # # save to pkl
# # if not closing_df.empty:
# #     closing_df.to_pickle('SSE companies closing prices.pkl')

# # cut into parts
# closing_df1 = closing_df.iloc[:, :int(np.floor(len(closing_df) / 2))]
# closing_df2 = closing_df.iloc[:, int(np.floor(len(closing_df) / 2)):]

# # save as pkl files
# if not closing_df1.empty and closing_df2.empty:
#     closing_df1.to_pickle('data/01 SSE companies closing prices.pkl')
#     closing_df2.to_pickle('data/02 SSE companies closing prices.pkl')

# %% [markdown]
# Note: The code above takes around 30-45 minutes to completely run.
